# %% [markdown]
# <a href="https://colab.research.google.com/github/lamaliang/2022_IPCS/blob/main/02_Read_CWB_Satation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd

# %%
# Using pandas to read html table
url = 'https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=466910&stname=%25E9%259E%258D%25E9%2583%25A8&datepicker=2022-02&altitude=837.6m'
table = pd.read_html(url,encoding='utf-8')[1]
table
# Out:
#    Unnamed: 0_level_0     press                                           \
#             觀測時間(day) 測站氣壓(hPa) 海平面氣壓(gpm) 測站最高氣壓(hPa)     測站最高氣壓時間(LST)
#               ObsTime   StnPres    SeaPres  StnPresMax    StnPresMaxTime
# 0                   1     924.9     1532.1       926.6  2022-02-01 22:00
# 1                   2     925.0     1536.5       926.6  2022-02-02 09:05
# 2                   3     923.2     1520.1       924.5  2022-02-03 00:25
# 3                   4     925.6     1537.1       928.0  2022-02-04 21:46
# 4                   5     928.5     1556.9       929.8  2022-02-05 21:23
# 5                   6     928.2     1555.5       930.8  2022-02-06 09:17
# 6                   7     923.1     1517.6       926.6  2022-02-07 00:01
# 7                   8     925.3     1533.9       927.1  2022-02-08 09:42
# 8                   9     924.5     1529.6       926.9  2022-02-09 09:27
# 9                  10     924.4     1532.2       926.5  2022-02-10 09:34
# ...

# %%
# Using Do loop to read html tables
yyyymm = [d.strftime('%Y-%m') for d in pd.date_range('2020-01','2020-12',freq='MS')]

# %%
dfs = []
for wd in yyyymm :
    url = 'https://e-service.cwb.gov.tw/HistoryDataQuery/MonthDataController.do?command=viewMain&station=466920&stname=%25E8%2587%25BA%25E5%258C%2597&datepicker='+wd+'&altitude=5.3m'
    dfs.append(pd.read_html(url,encoding='utf-8')[1].loc(axis=1)[:,:,['ObsTime','Temperature']])
df = pd.concat(dfs)
dfs.clear()
df
# Out:
#    Unnamed: 0_level_0 temperature
#             觀測時間(day)       氣溫(℃)
#               ObsTime Temperature
# 0                   1        16.0
# 1                   2        19.9
# 2                   3        21.0
# 3                   4        21.1
# 4                   5        22.1
# ..                ...         ...
# 26                 27        19.7
# 27                 28        20.2
# 28                 29        21.6
# 29                 30        12.7
# 30                 31         9.9
#
# [366 rows x 2 columns]

# %%
time = pd.date_range(start='2020-01-01', periods=366)
df.index = time
df.columns = ['day','temperature']
fig = px.line(df, x=df.index,y='temperature',color=px.Constant('Temp'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
